# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread(r'C:\Users\sharo\Desktop\OpenCV\from_start\data\leonal messi.jpg')

# %%
plt.imshow(img)

# %%
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #converting to rgb

# %%
plt.imshow(img)

# %%
txt_img = cv.putText(img,text='messi',org=(50,250),fontFace=cv.FONT_HERSHEY_DUPLEX,fontScale=1,color=(255,0,0),thickness=2)

# %%
plt.imshow(txt_img)
